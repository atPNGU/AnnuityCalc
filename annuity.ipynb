# %%
import pandas as pd
df_1 = pd.read_csv("tableau.csv")

print(df_1)
# Out:
#      monat  zinsen  tilgung
# 0        1  474.28   777.50
# 1        2  473.09   778.69
# 2        3  471.90   779.88
# 3        4  470.71   781.07
# 4        5  469.52   782.26
# ..     ...     ...      ...
# 179    180  230.45  1021.33
# 180    181  228.90  1022.88
# 181    182  227.34  1024.44
# 182    183  225.77  1026.01
# 183    184  224.21  1027.57
#
# [184 rows x 3 columns]

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df = pd.read_csv("tableau.csv")

x = np.array(df)

plt.plot(x)
plt.xlabel("Monate")
plt.ylabel("Betrag in EUR")
plt.title("Verlauf")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
